# %%
import Encoder
from EntityGraph import EntityGraph

# %%
g = EntityGraph()
# Out:
# No context for GraphConstructor. Working with toy example.
# 2020-02-25 11:47:39,788 loading file /home/simon/.flair/models/en-ner-conll03-v0.4.pt
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-960e59ecf975> in <module>()
# ----> 1 g = EntityGraph()
#
# /home/simon/Desktop/LCT_Saabrücken/Courses/AQA/project_AQA/modules/EntityGraph.py in __init__(self, context, tagger, max_nodes)
#      72         self.discarded_nodes = {}
#      73
# ---> 74         self._find_nodes(tag_with=tagger)
#      75         self._connect_nodes()
#      76         self._add_entity_spans()
#
# /home/simon/Desktop/LCT_Saabrücken/Courses/AQA/project_AQA/modules/EntityGraph.py in _find_nodes(self, tag_with)
#     138
#     139         elif tag_with == 'flair':
# --> 140             tagger = SequenceTagger.load('ner')
# ...
